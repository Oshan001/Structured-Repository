# %%
for i in range(100):
  print("hello world")
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# ...

# %%
print(2+2)
# Out:
# 4

# %%
print("\'OSHAN\'")
# Out:
# 'OSHAN'

# %%
a = "oshan"
age =21
prog="BCE"
print("my name is",a,"i am ",age,"years old","and i am studying",prog)
# Out:
# my name is oshan i am  21 years old and i am studying BCE

# %%
a = input("enter your name: ")
b= int(input("enter your age: "))
c=int(input("enter your roll number: "))
print("my name is",a,"i am ",b,"years old","and my roll number is",c)

# %%
a = input("enter your name: ")
b= int(input("enter your age: "))
c=int(input("enter your roll number: "))
print(f"name {a} age {b} roll number {c}")
# Out:
# nameOshan age20 roll number28

# %%
a=2+8j
b= 3+4j
c = a + b
print(c)
# Out:
# (5+12j)

# %%
a = int(input("enter a number: "))
b= int(input("input second number: "))
if a> b:
    print("a is greater than b")
elif a < b:
    print("b is greater than a")
5
# Out:
# b is greater than a
# 5

# %%
a=2+8j
b= 3+4j
c = a + b
print(c.real,"\n")
# Out:
# 5.0

# %%
print(c.conjugate())
# Out:
# (5-12j)

# %%
a = 'I am learning python'
# a[2] = "r"
print(a)
# Out:
# oshan

# %%
a = 'I am learning python'
b =  a[1:-1]
# b =  a[1:len(a)-1] '''same'''
print(b)
# Out:
#  am learning pytho

# %%
print(a[::-1])
# Out:
# nohtyp gninrael ma I

# %%
text = "            hello woRld"
print("1",text.lower())
print("2",text.upper())
print("3",text.capitalize())
print("4",text.title())
print("5",text.strip())
print('6',text.replace("World","Oshan"))
print("7",text.split(" ",-1))
# Out:
# 1             hello world
# 2             HELLO WORLD
# 3             hello world
# 4             Hello World
# 5 hello woRld
# 6             hello woRld
# 7 ['', '', '', '', '', '', '', '', '', '', '', '', 'hello', 'woRld']
