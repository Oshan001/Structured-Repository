# %% [markdown]
# # Tasks 1
# * Create list and add 5 element
# * Print first and last element of list

# %%
# create list and add 5 element 
list1 = [1,True,3.14,"hello",3]
print("------------------------------")
# print first and last element of list
print(list1[0],"\t",list1[4])
print("------------------------------")
# replce 3rd element with another value and print list
list1[2]=  0
print(list1)
# Out:
# 1 	 3
# [1, True, 0, 'hello', 3]

# %% [markdown]
# # Task 2:
# * create the list of integers value
# * add two element
# * remove 2 element
# * slot the list in ascending order
# *  reverse the list

# %%
# create the list of integers value
list2 = [1,2,3,4,5,66,0,4,-1]
print("------------------------------")
# add two element
list2.append(6)
list2.append(7)
print("------------------------------")
# remove 2 element
list2.remove(2)
list2.remove(4) 
print("------------------------------")
# slot the list in ascending order 
list2.sort()
print("------------------------------")
# reverse the list
list2.reverse()
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# # Task3 :
# * create 3*3 matrix
# * print all emement of matrix in diagonal order
# *  multiply two matrix
# * multiply two matrix

# %%
# create 3*3 matrix
matrix = [[1,2,3],[4,5,6],[7,8,9]]
# print all emement of matrix in diagonal order
for i in range(len(matrix)):
    print(matrix[i][i])
# add two matrix
matrix.append([10,11,12])
matrix.append([13,14,15])

print("------------------------------")

matrix1 = [[1,2],[4,5]]
matrix2 = [[10,11],[13,13]]
# add two matrix
mat=[[0,0],[0,0]]
for i in range(len(matrix1)):
    for j in range(len(matrix2)):
        mat [i][j] = matrix1[i][j] + matrix2[i][j]
        print(mat, end=" ")
    print()

print("------------------------------")
# multiply two matrix
for i in range(len(matrix1)):
    for j in range(len(matrix2)):
        sum = 0
        for k in range(len(matrix2)):
            sum += matrix1[i][k] * matrix2[k][j]
        print(sum, end=" ")
    print()
# Out:
# 1
# 5
# 9
# ------------------------------
# 11 13
# 17 18
# ------------------------------
# 36 37
# 105 109
