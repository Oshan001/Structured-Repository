# %% [markdown]
# Matplotlib: Matplotlib is mainly deployed for basic plotting. Visualization using Matplotlib generally consists of bars, pies, lines, scatter plots and so on. Seaborn: Seaborn, on the other hand, provides a variety of visualization patterns. It uses fewer syntax and has easily interesting default themes
#
# Pandas is primarily used for data analysis. It supports working with tabular data like CSV, Excel sheets, etc. NumPy, by default, supports data in the form of matrices and arrays since it is focused on numerical computations

# %%
# pip install seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure

# %%
##Define our dataset
dataset = [10,11,12,13,14,15,16,17,18,20,22,24,25,26,30,34,32,33,40,45,50,55,60,90,120,180]

# %%
# First Figure
plt.figure(1)
plt.grid(True)
sns.histplot(dataset, color='r', kde=True)

# Second Figure
plt.figure(2)
plt.grid(True)
sns.histplot(dataset)

plt.show()

# %%
## Z score
outliers =[]
#function to take data as argument and return possible outliers
def detect_outliers(data):
    threshold =3 # here 3 is standard deviation
    mean = np.mean(data)
    std = np.std(data)
    for i in data:
        z_score = (i-mean)/std
        if np.abs(z_score)>threshold:
            outliers.append(i)
    return outliers

# %%
detect_outliers(dataset)


# IQR ( InterQuartile Range)
# 1. Sort the data
# 2. Calculate Q1 and Q3
# 3. IQR = (Q3 - Q1 )
# 4. Find the Lower fence(q1 - 1.5(iqr))
# 5. Find upper fence(q3 + 1.5(iqr))
# Out:
# [180]

# %% [markdown]
# IQR: the interquartile range tells you the spread of the middle half of your distribution. Quartiles segment any distribution that's ordered from low to high into four equal parts. The interquartile range (IQR) contains the second and third quartiles, or the middle half of your data set.

# %%
dataset = sorted(dataset)
#data set



q1,q2,q3 = np.percentile(dataset,[25,50,75])
#(q1=median of upper half)
#(q3=median of lower half)
#(q2=median of whole table)

# %%
print(q1,q2,q3)
# Out:
# 16.25 25.5 43.75

# %%
iqr = q3-q1
print(iqr)
# Out:
# 27.5

# %% [markdown]
# upper and lower fences represent the cut-off values for upper and lower outliers in a dataset

# %%
#Find the Lower fence and higher fence
lower_fence=q1-(1.5*iqr)
higher_fence=q3+(1.5*iqr)

print(lower_fence,higher_fence)
# Out:
# -25.0 85.0

# %%
#Remove the outliers which doesnot belongs to lower -->higher fence range
outliers =[]
for item in dataset:
    if item<lower_fence or item>higher_fence:
        outliers.append(item)

print("outlines:    ",outliers)
print('items:    ',item)
# Out:
# outlines:     [90, 120, 180]
# items:     180

# %%
import seaborn as sns
plt.grid(True)
sns.boxplot(dataset)
# Out:
# <Axes: >

# %%
for item in outliers:
    dataset.remove(item)
print(item)
# Out:
# 180

# %%
sns.boxplot(dataset)
# Out:
# <Axes: >
