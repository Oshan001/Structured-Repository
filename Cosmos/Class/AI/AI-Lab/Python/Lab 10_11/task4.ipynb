# %%
import matplotlib.pyplot as plt

# %%
year=[2014,2015,2016,2017]
income=[4000,4500,5300,4600]
expense=[2800,3000,2800,3400]

plt.subplot(2,1,1)# (row, col, position)
plt.title('Income and Expense')
plt.xlabel("Year")
plt.ylabel("Income")
plt.bar(year,income,color='red',label='income')
plt.legend()

plt.subplot(2,1,2)
plt.bar(year,expense,color='green',label='expense')
plt.xlabel("Year")
plt.ylabel('Expense')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 income=[4000,4500,5300,4600]
#       3 expense=[2800,3000,2800,3400]
# ----> 5 plt.subplot(2,1,1)# (row, col, position)
#       6 plt.title('Income and Expense')
#       7 plt.xlabel("Year")
#
# NameError: name 'plt' is not defined

# %%
year=[2014,2015,2016,2017]
income=[4000,4500,5300,4600]
expense=[2800,3000,2800,3400]

plt.subplot(2,1,1)# (row, col, position)
plt.title('Income and Expense')
plt.xlabel("Year")
plt.ylabel("Income")
plt.bar(year,income,color='red',label='income')
plt.legend()

plt.subplot(2,1,2)
plt.bar(year,expense,color='green',label='expense')
plt.xlabel("Year")
plt.ylabel('Expense')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       2 income=[4000,4500,5300,4600]
#       3 expense=[2800,3000,2800,3400]
# ----> 5 plt.subplot(2,1,1)# (row, col, position)
#       6 plt.title('Income and Expense')
#       7 plt.xlabel("Year")
#
# NameError: name 'plt' is not defined
